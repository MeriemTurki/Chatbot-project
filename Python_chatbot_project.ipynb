# %%
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import json
import pickle

import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.optimizers import SGD
import random

words=[]
classes = []
documents = []
ignore_words = ['?', '!']
data_file = open("intents.json", "r")
intents = json.load(data_file)

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
for intent in intents['intents']:
    for pattern in intent['patterns']:

        #tokenize each word
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        #add documents in the corpus
        documents.append((w, intent['tag']))

        # add to our classes list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

# %%
import nltk
nltk.download('wordnet')
import nltk
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
# lemmatize, lower each word and remove duplicates
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))
# sort classes
classes = sorted(list(set(classes)))
# documents = combination between patterns and intents
print (len(documents), "documents")
# classes = intents
print (len(classes), "classes", classes)
# words = all words, vocabulary
print (len(words), "unique lemmatized words", words)

pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))
# Out:
# 47 documents
# 9 classes ['adverse_drug', 'blood_pressure', 'blood_pressure_search', 'goodbye', 'greeting', 'hospital_search', 'options', 'pharmacy_search', 'thanks']
# 88 unique lemmatized words ["'s", ',', 'a', 'adverse', 'all', 'anyone', 'are', 'awesome', 'be', 'behavior', 'blood', 'by', 'bye', 'can', 'causing', 'chatting', 'check', 'could', 'data', 'day', 'detail', 'do', 'dont', 'drug', 'entry', 'find', 'for', 'give', 'good', 'goodbye', 'have', 'hello', 'help', 'helpful', 'helping', 'hey', 'hi', 'history', 'hola', 'hospital', 'how', 'i', 'id', 'is', 'later', 'list', 'load', 'locate', 'log', 'looking', 'lookup', 'management', 'me', 'module', 'nearby', 'next', 'nice', 'of', 'offered', 'open', 'patient', 'pharmacy', 'pressure', 'provide', 'reaction', 'related', 'result', 'search', 'searching', 'see', 'show', 'suitable', 'support', 'task', 'thank', 'thanks', 'that', 'there', 'till', 'time', 'to', 'transfer', 'up', 'want', 'what', 'which', 'with', 'you']

# %%
# create our training data
training = []
# create an empty array for our output
output_empty = [0] * len(classes)
# training set, bag of words for each sentence
for doc in documents:
    # initialize our bag of words
    bag = []
    # list of tokenized words for the pattern
    pattern_words = doc[0]
    # lemmatize each word - create base word, in attempt to represent related words
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    # create our bag of words array with 1, if word match found in current pattern
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)

    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1

    training.append([bag, output_row])
# shuffle our features and turn into np.array
random.shuffle(training)
training = np.array(training)
# create train and test lists. X - patterns, Y - intents
train_x = list(training[:,0])
train_y = list(training[:,1])
print("Training data created")
# Out:
# Training data created
# <ipython-input-56-451aefdaa425>:24: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   training = np.array(training)

# %%
# Create model - 3 layers. First layer 128 neurons, second layer 64 neurons and 3rd output layer contains number of neurons
# equal to number of intents to predict output intent with softmax
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# Compile model. Stochastic gradient descent with Nesterov accelerated gradient gives good results for this model
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

#fitting and saving the model 
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('chatbot_model.h5', hist)

print("model created")
# Out:
# /usr/local/lib/python3.8/dist-packages/keras/optimizers/optimizer_v2/gradient_descent.py:108: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# Epoch 1/200
# 10/10 [==============================] - 1s 12ms/step - loss: 2.2914 - accuracy: 0.0426
# Epoch 2/200
# 10/10 [==============================] - 0s 4ms/step - loss: 2.2015 - accuracy: 0.0638
# Epoch 3/200
# 10/10 [==============================] - 0s 4ms/step - loss: 2.0768 - accuracy: 0.2128
# Epoch 4/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.9164 - accuracy: 0.3830
# Epoch 5/200
# 10/10 [==============================] - 0s 8ms/step - loss: 1.8939 - accuracy: 0.3830
# Epoch 6/200
# 10/10 [==============================] - 0s 7ms/step - loss: 1.7923 - accuracy: 0.3617
# Epoch 7/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.6233 - accuracy: 0.5106
# Epoch 8/200
# 10/10 [==============================] - 0s 9ms/step - loss: 1.4835 - accuracy: 0.5745
# Epoch 9/200
# 10/10 [==============================] - 0s 8ms/step - loss: 1.3276 - accuracy: 0.6596
# Epoch 10/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3715 - accuracy: 0.5532
# Epoch 11/200
# 10/10 [==============================] - 0s 5ms/step - loss: 1.1060 - accuracy: 0.7447
# Epoch 12/200
# 10/10 [==============================] - 0s 5ms/step - loss: 1.1883 - accuracy: 0.6383
# Epoch 13/200
# 10/10 [==============================] - 0s 6ms/step - loss: 1.0143 - accuracy: 0.7021
# Epoch 14/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.8274 - accuracy: 0.8085
# Epoch 15/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.7946 - accuracy: 0.8298
# Epoch 16/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5893 - accuracy: 0.8723
# Epoch 17/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.6163 - accuracy: 0.8085
# Epoch 18/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6137 - accuracy: 0.8085
# Epoch 19/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.6209 - accuracy: 0.8085
# Epoch 20/200
# 10/10 [==============================] - 0s 13ms/step - loss: 0.4777 - accuracy: 0.9149
# Epoch 21/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.5594 - accuracy: 0.8298
# Epoch 22/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.4529 - accuracy: 0.8936
# Epoch 23/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5370 - accuracy: 0.7872
# Epoch 24/200
# 10/10 [==============================] - 0s 9ms/step - loss: 0.3834 - accuracy: 0.8936
# Epoch 25/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.4528 - accuracy: 0.9149
# Epoch 26/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.3004 - accuracy: 0.9362
# Epoch 27/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4923 - accuracy: 0.8511
# Epoch 28/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2508 - accuracy: 0.9362
# Epoch 29/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3026 - accuracy: 0.9362
# Epoch 30/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1691 - accuracy: 0.9574
# Epoch 31/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3479 - accuracy: 0.9149
# Epoch 32/200
# 10/10 [==============================] - 0s 14ms/step - loss: 0.2227 - accuracy: 0.9362
# Epoch 33/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1587 - accuracy: 1.0000
# Epoch 34/200
# 10/10 [==============================] - 0s 9ms/step - loss: 0.2462 - accuracy: 0.9362
# Epoch 35/200
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1705 - accuracy: 0.9574
# Epoch 36/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2571 - accuracy: 0.9574
# Epoch 37/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1292 - accuracy: 0.9574
# Epoch 38/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1600 - accuracy: 0.9574
# Epoch 39/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2149 - accuracy: 0.9574
# Epoch 40/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1770 - accuracy: 0.9574
# Epoch 41/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0963 - accuracy: 0.9787
# Epoch 42/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1478 - accuracy: 0.9574
# Epoch 43/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1589 - accuracy: 0.9574
# Epoch 44/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1250 - accuracy: 0.9574
# Epoch 45/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0738 - accuracy: 1.0000
# Epoch 46/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1695 - accuracy: 0.9362
# Epoch 47/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1753 - accuracy: 0.9362
# Epoch 48/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0923 - accuracy: 0.9787
# Epoch 49/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0712 - accuracy: 1.0000
# Epoch 50/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1170 - accuracy: 0.9787
# Epoch 51/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1029 - accuracy: 0.9787
# Epoch 52/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1236 - accuracy: 0.9787
# Epoch 53/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1009 - accuracy: 0.9787
# Epoch 54/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0817 - accuracy: 0.9787
# Epoch 55/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0980 - accuracy: 0.9787
# Epoch 56/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0598 - accuracy: 1.0000
# Epoch 57/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0817 - accuracy: 0.9574
# Epoch 58/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0739 - accuracy: 0.9787
# Epoch 59/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1065 - accuracy: 0.9787
# Epoch 60/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0408 - accuracy: 1.0000
# Epoch 61/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0990 - accuracy: 0.9574
# Epoch 62/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0413 - accuracy: 1.0000
# Epoch 63/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0358 - accuracy: 1.0000
# Epoch 64/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0392 - accuracy: 1.0000
# Epoch 65/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0167 - accuracy: 1.0000
# Epoch 66/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0712 - accuracy: 1.0000
# Epoch 67/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0448 - accuracy: 1.0000
# Epoch 68/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1051 - accuracy: 0.9787
# Epoch 69/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1192 - accuracy: 0.9574
# Epoch 70/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0895 - accuracy: 0.9787
# Epoch 71/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0594 - accuracy: 0.9787
# Epoch 72/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0340 - accuracy: 1.0000
# Epoch 73/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0411 - accuracy: 1.0000
# Epoch 74/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0221 - accuracy: 1.0000
# Epoch 75/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1348 - accuracy: 0.9787
# Epoch 76/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0269 - accuracy: 1.0000
# Epoch 77/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1298 - accuracy: 0.9787
# Epoch 78/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0959 - accuracy: 0.9574
# Epoch 79/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0209 - accuracy: 1.0000
# Epoch 80/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0395 - accuracy: 1.0000
# Epoch 81/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0550 - accuracy: 1.0000
# Epoch 82/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0455 - accuracy: 1.0000
# Epoch 83/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0562 - accuracy: 0.9787
# Epoch 84/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0316 - accuracy: 1.0000
# Epoch 85/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0589 - accuracy: 0.9574
# Epoch 86/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0486 - accuracy: 0.9787
# Epoch 87/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0518 - accuracy: 1.0000
# Epoch 88/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0373 - accuracy: 1.0000
# Epoch 89/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0489 - accuracy: 0.9787
# Epoch 90/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0485 - accuracy: 1.0000
# Epoch 91/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0254 - accuracy: 1.0000
# Epoch 92/200
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0517 - accuracy: 0.9787
# Epoch 93/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0885 - accuracy: 0.9787
# Epoch 94/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0519 - accuracy: 0.9787
# Epoch 95/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0469 - accuracy: 1.0000
# Epoch 96/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0662 - accuracy: 0.9787
# Epoch 97/200
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0722 - accuracy: 0.9787
# Epoch 98/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0796 - accuracy: 0.9787
# Epoch 99/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0575 - accuracy: 0.9787
# Epoch 100/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0206 - accuracy: 1.0000
# Epoch 101/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0706 - accuracy: 0.9787
# Epoch 102/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0791 - accuracy: 0.9787
# Epoch 103/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0285 - accuracy: 1.0000
# Epoch 104/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0630 - accuracy: 0.9787
# Epoch 105/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0678 - accuracy: 0.9787
# Epoch 106/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0516 - accuracy: 0.9787
# Epoch 107/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0317 - accuracy: 1.0000
# Epoch 108/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0362 - accuracy: 0.9787
# Epoch 109/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0248 - accuracy: 1.0000
# Epoch 110/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0428 - accuracy: 0.9787
# Epoch 111/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0190 - accuracy: 1.0000
# Epoch 112/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0150 - accuracy: 1.0000
# Epoch 113/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0127 - accuracy: 1.0000
# Epoch 114/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0105 - accuracy: 1.0000
# Epoch 115/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0614 - accuracy: 0.9574
# Epoch 116/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0601 - accuracy: 0.9787
# Epoch 117/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0635 - accuracy: 0.9787
# Epoch 118/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0535 - accuracy: 0.9787
# Epoch 119/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0229 - accuracy: 1.0000
# Epoch 120/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0495 - accuracy: 1.0000
# Epoch 121/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0412 - accuracy: 1.0000
# Epoch 122/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0225 - accuracy: 1.0000
# Epoch 123/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0109 - accuracy: 1.0000
# Epoch 124/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0565 - accuracy: 0.9787
# Epoch 125/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0320 - accuracy: 1.0000
# Epoch 126/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0525 - accuracy: 0.9574
# Epoch 127/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0272 - accuracy: 1.0000
# Epoch 128/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0427 - accuracy: 1.0000
# Epoch 129/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0153 - accuracy: 1.0000
# Epoch 130/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0763 - accuracy: 0.9574
# Epoch 131/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0090 - accuracy: 1.0000
# Epoch 132/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0166 - accuracy: 1.0000
# Epoch 133/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0130 - accuracy: 1.0000
# Epoch 134/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0851 - accuracy: 0.9574
# Epoch 135/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0143 - accuracy: 1.0000
# Epoch 136/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0563 - accuracy: 1.0000
# Epoch 137/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1354 - accuracy: 0.9362
# Epoch 138/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0460 - accuracy: 0.9787
# Epoch 139/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0124 - accuracy: 1.0000
# Epoch 140/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0127 - accuracy: 1.0000
# Epoch 141/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0612 - accuracy: 0.9574
# Epoch 142/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0269 - accuracy: 1.0000
# Epoch 143/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0278 - accuracy: 1.0000
# Epoch 144/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0440 - accuracy: 0.9787
# Epoch 145/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0255 - accuracy: 1.0000
# Epoch 146/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0407 - accuracy: 1.0000
# Epoch 147/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0133 - accuracy: 1.0000
# Epoch 148/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0080 - accuracy: 1.0000
# Epoch 149/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 150/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0261 - accuracy: 1.0000
# Epoch 151/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0253 - accuracy: 1.0000
# Epoch 152/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0157 - accuracy: 1.0000
# Epoch 153/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0697 - accuracy: 0.9574
# Epoch 154/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0112 - accuracy: 1.0000
# Epoch 155/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0078 - accuracy: 1.0000
# Epoch 156/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0414 - accuracy: 0.9787
# Epoch 157/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0476 - accuracy: 0.9787
# Epoch 158/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0044 - accuracy: 1.0000
# Epoch 159/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0139 - accuracy: 1.0000
# Epoch 160/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0503 - accuracy: 1.0000
# Epoch 161/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0645 - accuracy: 0.9787
# Epoch 162/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0632 - accuracy: 0.9787
# Epoch 163/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0569 - accuracy: 0.9787
# Epoch 164/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0843 - accuracy: 0.9787
# Epoch 165/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0101 - accuracy: 1.0000
# Epoch 166/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0045 - accuracy: 1.0000
# Epoch 167/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0179 - accuracy: 1.0000
# Epoch 168/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0184 - accuracy: 1.0000
# Epoch 169/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0202 - accuracy: 1.0000
# Epoch 170/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0996 - accuracy: 0.9787
# Epoch 171/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0199 - accuracy: 1.0000
# Epoch 172/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0097 - accuracy: 1.0000
# Epoch 173/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0502 - accuracy: 0.9787
# Epoch 174/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0402 - accuracy: 0.9787
# Epoch 175/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0532 - accuracy: 1.0000
# Epoch 176/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0306 - accuracy: 0.9787
# Epoch 177/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0192 - accuracy: 1.0000
# Epoch 178/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0616 - accuracy: 0.9574
# Epoch 179/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0402 - accuracy: 0.9787
# Epoch 180/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0431 - accuracy: 0.9787
# Epoch 181/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0290 - accuracy: 0.9787
# Epoch 182/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0154 - accuracy: 1.0000
# Epoch 183/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0181 - accuracy: 1.0000
# Epoch 184/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0193 - accuracy: 1.0000
# Epoch 185/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0191 - accuracy: 1.0000
# Epoch 186/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0238 - accuracy: 1.0000
# Epoch 187/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0646 - accuracy: 0.9787
# Epoch 188/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0129 - accuracy: 1.0000
# Epoch 189/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0121 - accuracy: 1.0000
# Epoch 190/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0180 - accuracy: 1.0000
# Epoch 191/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0210 - accuracy: 1.0000
# Epoch 192/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0333 - accuracy: 1.0000
# Epoch 193/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0052 - accuracy: 1.0000
# Epoch 194/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0368 - accuracy: 1.0000
# Epoch 195/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0100 - accuracy: 1.0000
# Epoch 196/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0440 - accuracy: 0.9787
# Epoch 197/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0081 - accuracy: 1.0000
# Epoch 198/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0669 - accuracy: 0.9787
# Epoch 199/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0099 - accuracy: 1.0000
# Epoch 200/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0139 - accuracy: 1.0000
# model created

# %%
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import pickle
import numpy as np

from keras.models import load_model
model = load_model('chatbot_model.h5')
import json
import random
intents = json.loads(open('intents.json').read())
words = pickle.load(open('words.pkl','rb'))
classes = pickle.load(open('classes.pkl','rb'))

# %%
def clean_up_sentence(sentence):
    # tokenize the pattern - split words into array
    sentence_words = nltk.word_tokenize(sentence)
    # stem each word - create short form for word
    sentence_words = [lemmatizer.lemmatize(word.lower()) for word in sentence_words]
    return sentence_words
# return bag of words array: 0 or 1 for each word in the bag that exists in the sentence

def bow(sentence, words, show_details=True):
    # tokenize the pattern
    sentence_words = clean_up_sentence(sentence)
    # bag of words - matrix of N words, vocabulary matrix
    bag = [0]*len(words) 
    for s in sentence_words:
        for i,w in enumerate(words):
            if w == s: 
                # assign 1 if current word is in the vocabulary position
                bag[i] = 1
                if show_details:
                    print ("found in bag: %s" % w)
    return(np.array(bag))

def predict_class(sentence, model):
    # filter out predictions below a threshold
    p = bow(sentence, words,show_details=False)
    res = model.predict(np.array([p]))[0]
    ERROR_THRESHOLD = 0.25
    results = [[i,r] for i,r in enumerate(res) if r>ERROR_THRESHOLD]
    # sort by strength of probability
    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in results:
        return_list.append({"intent": classes[r[0]], "probability": str(r[1])})
    return return_list

# %%
def getResponse(ints, intents_json):
    tag = ints[0]['intent']
    list_of_intents = intents_json['intents']
    for i in list_of_intents:
        if(i['tag']== tag):
            result = random.choice(i['responses'])
            break
    return result

def chatbot_response(text):
    ints = predict_class(text, model)
    res = getResponse(ints, intents)
    return res

# %%
# !apt-get install -y xvfb # Install X Virtual Frame Buffer
import os
os.system('Xvfb :1 -screen 0 1600x1200x16  &')    # create virtual display with size 1600x1200 and 16 bit color. Color can be changed to 24 or 8
os.environ['DISPLAY']=':1.0'    # tell X clients to use our virtual DISPLAY :1.0
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# xvfb is already the newest version (2:1.19.6-1ubuntu4.12).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 7 not upgraded.

# %%
#Creating GUI with tkinter
import tkinter
from tkinter import *


def send():
    msg = EntryBox.get("1.0",'end-1c').strip()
    EntryBox.delete("0.0",END)

    if msg != '':
        ChatLog.config(state=NORMAL)
        ChatLog.insert(END, "You: " + msg + '\n\n')
        ChatLog.config(foreground="#442265", font=("Verdana", 12 ))

        res = chatbot_response(msg)
        ChatLog.insert(END, "Bot: " + res + '\n\n')

        ChatLog.config(state=DISABLED)
        ChatLog.yview(END)

base = Tk()
base.title("Hello")
base.geometry("400x500")
base.resizable(width=FALSE, height=FALSE)

#Create Chat window
ChatLog = Text(base, bd=0, bg="white", height="8", width="50", font="Arial",)

ChatLog.config(state=DISABLED)

#Bind scrollbar to Chat window
scrollbar = Scrollbar(base, command=ChatLog.yview, cursor="heart")
ChatLog['yscrollcommand'] = scrollbar.set

#Create Button to send message
SendButton = Button(base, font=("Verdana",12,'bold'), text="Send", width="12", height=5,
                    bd=0, bg="#32de97", activebackground="#3c9d9b",fg='#ffffff',
                    command= send )

#Create the box to enter message
EntryBox = Text(base, bd=0, bg="white",width="29", height="5", font="Arial")
#EntryBox.bind("<Return>", send)


#Place all components on the screen
scrollbar.place(x=376,y=6, height=386)
ChatLog.place(x=6,y=6, height=386, width=370)
EntryBox.place(x=128, y=401, height=90, width=265)
SendButton.place(x=6, y=401, height=90)

base.mainloop()

# %%
python train_chatbot.py

# %%
python chatgui.py
